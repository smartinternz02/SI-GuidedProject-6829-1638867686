# %%
pow(7,4)
# Out:
# 2401

# %%
s="Hi there sam!"
print(s.split())
# Out:
# ['Hi', 'there', 'sam!']

# %%
planet="Earth"
diameter=12742
print("The diameter of {} is {}".format(planet,diameter))
# Out:
# The diameter of Earth is 12742

# %%
lst=[1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]
print(lst[3][1][2][0])
# Out:
# hello

# %%
d={'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}
print(d['k1'][3]['tricky'][3]['target'][3])
# Out:
# hello

# %%
# A tuple is immutable
# A list is mutable

# %%
def fun():
    str=input("Enter website")
    s=str.split('@')
    print(s[1])
fun()
# Out:
# Enter website user@domain.com
# domain.com

# %%
def find():
    stri=input("Enter string").lower()
    if('dog' in stri):
        print("True")
    else:
        print("False")
find()
# Out:
# Enter string german dog
# True

# %%
find()
# Out:
# Enter string Welcome to python
# False

# %%
seq=['soup','dog','salad','cat','great']
s=list(filter(lambda i:i.startswith('s'),seq))
print(s)
# Out:
# ['soup', 'salad']

# %%
a=int(input("Enter speed"))
b=input("Is your birthday?")
def speed(a,b):
    if b:
        a=a+5
        if a<=61:
            print("No ticket")
        elif a>61 and a<80:
            print("Small ticket")
        else:
            print("Big ticket")
speed(a,b)
# Out:
# Enter speed 75
# Is your birthday? true
# Big ticket
